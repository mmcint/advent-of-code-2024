# %% [markdown]
# <a href="https://colab.research.google.com/github/mmcint/advent-of-code-2024/blob/main/2024_AoC_12_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('day1_data.txt',sep="\s+",header=None, names=["Column1", "Column2"])

# %%
out_df = pd.concat([data['Column1'].sort_values(ascending=True).reset_index(drop=True), data['Column2'].sort_values(ascending=True).reset_index(drop=True)], axis=1)

# %%
out_df
# Out:
#      Column1  Column2
# 0      10004    10010
# 1      10484    10083
# 2      10539    10303
# 3      10609    10537
# 4      10721    10899
# ..       ...      ...
# 995    99765    99650
# 996    99826    99650
# 997    99876    99650
# 998    99885    99650
# 999    99974    99689
#
# [1000 rows x 2 columns]

# %%
out_df['diff'] = np.abs(out_df['Column1'] - out_df['Column2'])

# %%
print('Answer: {}'.format(np.sum(out_df['diff'])))
# Out:
# Answer: 1603498

# %% [markdown]
# # Part 2

# %%
score_dict = {}
count = 0
for i in list(data['Column1']):
  count = 0
  for j in list(data['Column2']):
    if i == j:
      count += 1
    else:
      pass
    score_dict[i] = count

# %%
sim_score = 0
for k, v in score_dict.items():
  sim_score += (k * v)
print('Answer: {}'.format(sim_score))
# Out:
# Answer: 25574739
